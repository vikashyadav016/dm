# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Generate random data for the histogram
# data = organizations-100
# math_scores = [72, 41, 65, 63, 82, 63, 51, 57, 39, 63,
#                62, 68, 52, 76, 62, 73, 72, 73, 71, 62,
#                76, 53, 71, 79, 77, 35, 65, 59, 58, 70,
#                73, 69, 59, 75, 73, 63, 65, 81, 46, 59,
#                53, 71, 79, 80, 60, 60, 64, 40, 73, 75,
#                68, 58, 81, 65, 55, 62, 82, 47, 85, 62,
#                39, 77, 82, 78, 57, 58, 72, 75, 65, 68,
#                86, 49, 39, 64, 54, 68, 85, 77, 62, 53,
#                52, 76, 80, 84, 69, 61, 69, 65, 89, 97,
#                71, 61, 77, 40, 83, 52, 78, 54, 64, 58]
dataset = pd.read_csv('organizations-100.csv')
# df=dataset.head()
df = pd.DataFrame(dataset)
# print(df)
df1= df[["Number of employees"]]
df1
df2= df[["Founded"]]
df2

plt.scatter(df1, df2, c ="blue")
plt.show()
# Plotting a basic histogram
# plt.hist(math_scores, bins="auto", color='skyblue', edgecolor='black')

# # Adding labels and title
# plt.xlabel('Values')
# plt.ylabel('Frequency')
# plt.title('Basic Histogram')

# # Display the plot
# plt.show()
